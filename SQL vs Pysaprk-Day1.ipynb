# %%
# SQl - table
# pyspark - Dataframe(depends upon the situvation the way of calling dataframe is different)

# %%
#variable - store the some information
# python - reveserve keywords, try, class, def, except, finally, for, if, import, in, is, lambda, return, try, while, with, yield

# %%
# %sql
create table employees(
    emp_id int,
    emp_name varchar(50),
    department varchar(50),
    salary int,
    age int,
    city varchar(50),
    exeperice int 
)

# %%
# here True means NUll values are allowed
# pyspark, python follows the indentation rule
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

# Define the schema matching the SQL table
schema = StructType([
    StructField("emp_id", IntegerType(), False),
    StructField("emp_name", StringType(), True),q
    StructField("department", StringType(), True),
    StructField("salary", IntegerType(), True),
    StructField("age", IntegerType(), True),
    StructField("city", StringType(), True),
    StructField("exeperice", IntegerType(), True)
])

# Create an empty DataFrame with the schema
df = spark.createDataFrame([], schema)
df.printSchema()

# %%
# %sql
insert into employees values
(101,'ravi','IT',60000,28,'hyderabad',5),
(102,'sai','HR',50000,25,'hyderabad',3),
(103,'suresh','IT',70000,30,'bangalore',7),
(104,'ramesh','IT',80000,35,'bangalore',10),
(105,'kumar','HR',55000,28,'bangalore',4),
(106,'santhosh','IT',65000,32,'bangalore',6),
(107,'sudharsan','IT',75000,38,'bangalore',8),
(108,'santhosh','IT',65000,32,'bangalore',6)

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

data = [
    (101, 'ravi', 'IT', 60000, 28, 'hyderabad', 5),
    (102, 'sai', 'HR', 50000, 25, 'hyderabad', 3),
    (103, 'suresh', 'IT', 70000, 30, 'bangalore', 7),
    (104, 'ramesh', 'IT', 80000, 35, 'bangalore', 10),
    (105, 'kumar', 'HR', 55000, 28, 'bangalore', 4),
    (106, 'santhosh', 'IT', 65000, 32, 'bangalore', 6),
    (107, 'sudharsan', 'IT', 75000, 38, 'bangalore', 8),
    (108, 'santhosh', 'IT', 65000, 32, 'bangalore', 6)
]

schema = StructType([
    StructField("emp_id", IntegerType(), False),
    StructField("emp_name", StringType(), True),
    StructField("department", StringType(), True),
    StructField("salary", IntegerType(), True),
    StructField("age", IntegerType(), True),
    StructField("city", StringType(), True),
    StructField("exeperice", IntegerType(), True)
])

df = spark.createDataFrame(data, schema)
display(df)

# %%
# %sql
select * from employees
